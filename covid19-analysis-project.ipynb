# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\hp\Desktop\python\task\data science\covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
#delete useless colume
df=dataset.drop(["Lat","Long"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#aggreagate
corona_dataset_aggregated= dataset.groupby("Country/Region").sum()

# %%
print(list(dataset.columns))
# Out:
# ['Province/State', 'Country/Region', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19/20', '4/20/20'
# ...

# %%
corona_dataset_aggregated.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
print(list(dataset.columns))
corona_dataset_aggregated.drop('Province/State',axis=1,inplace=True)
# Out:
# ['Province/State', 'Country/Region', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19/20', '4/20/20'
# ...

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %%
#corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["India"].plot()
data = corona_dataset_aggregated.loc["Spain"]          # Convert non-numeric to NaN
data = data.apply(pd.to_numeric, errors='coerce')  
data.plot()
plt.legend()

# %%
data = corona_dataset_aggregated.loc["China"][:3]
data = data.apply(pd.to_numeric, errors='coerce')  # Convert non-numeric to NaNdata.plot()
data.plot()
corona_dataset_aggregated.loc["India"][:3].plot()
# Out:
# <Axes: >

# %%
#first derivative
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc["China"].diff().max()
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
countries=list(corona_dataset_aggregated.index)
max_infection_rates=[]
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["Max_infaction_rates"]=max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_data=pd.DataFrame(corona_dataset_aggregated["Max_infaction_rates"])

# %%
corona_data
# Out:
#                     Max_infaction_rates
# Country/Region
# Afghanistan                       232.0
# Albania                            34.0
# Algeria                           199.0
# Andorra                            43.0
# Angola                              5.0
# ...                                 ...
# West Bank and Gaza                 66.0
# Western Sahara                      4.0
# Yemen                               5.0
# Zambia                              9.0
# Zimbabwe                            8.0
#
# [187 rows x 1 columns]

# %%
happiness_report=pd.read_csv(r"C:\Users\hp\Desktop\python\task\data science\worldwide_happiness_report.csv")

# %%
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#drop columns
print(list(happiness_report.columns))
useless_col=['Overall rank','Score','Generosity','Perceptions of corruption']
#happiness_report.drop(useless_col,axis=1,inplace=True)
# Out:
# ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
print(list(happiness_report.columns))
happiness_report.set_index("Country or region",inplace=True)
# Out:
# ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# %%
happiness_report.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 8)

# %%
data=corona_data.join(happiness_report,how="inner")
data
# Out:
#              Max_infaction_rates  Overall rank  Score  GDP per capita  \
# Afghanistan                232.0           154  3.203           0.350
# Albania                     34.0           107  4.719           0.947
# Algeria                    199.0            88  5.211           1.002
# Argentina                  291.0            47  6.086           1.092
# Armenia                    134.0           116  4.559           0.850
# ...                          ...           ...    ...             ...
# Venezuela                   29.0           108  4.707           0.960
# Vietnam                     19.0            94  5.175           0.741
# Yemen                        5.0           151  3.380           0.287
# Zambia                       9.0           138  4.107           0.578
# Zimbabwe                     8.0           146  3.663           0.366
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.517                    0.361
# ...

# %%
data.corr()
# Out:
#                               Max_infaction_rates  Overall rank     Score  \
# Max_infaction_rates                      1.000000     -0.244777  0.228783
# Overall rank                            -0.244777      1.000000 -0.988972
# Score                                    0.228783     -0.988972  1.000000
# GDP per capita                           0.250118     -0.802204  0.793847
# Social support                           0.191958     -0.780955  0.788591
# Healthy life expectancy                  0.289263     -0.804753  0.799893
# Freedom to make life choices             0.078196     -0.570490  0.587007
# Generosity                              -0.114635     -0.063107  0.090420
# Perceptions of corruption                0.097703     -0.389360  0.420437
#
#                               GDP per capita  Social support  \
# Max_infaction_rates                 0.250118        0.191958
# Overall rank                       -0.802204       -0.780955
# ...

# %%
#visual
x=data["GDP per capita"]
y=data["Max_infaction_rates"]
#sns.scatterplot(x,np.log(y))
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infaction_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infaction_rates'>

# %%
x=data["Social support"]
y=data["Max_infaction_rates"]
#sns.scatterplot(x,np.log(y))
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infaction_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infaction_rates'>

# %%
x=data["Healthy life expectancy"]
y=data["Max_infaction_rates"]
#sns.scatterplot(x,np.log(y))
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infaction_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infaction_rates'>

# %%
x=data["Freedom to make life choices"]
y=data["Max_infaction_rates"]
#sns.scatterplot(x,np.log(y))
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infaction_rates'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infaction_rates'>
